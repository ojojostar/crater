# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import umap
from sklearn.datasets import load_digits
from sklearn.cluster import KMeans


# from sklearn.feature_selection import mutual_info_regression
# from sklearn.python import cross_val_score
# from xgboost import XGBRegressor

# %%
df = pd.read_csv(r"C:\Users\josep\Documents\Joseph\crater\M3_data.csv")
df2 = df

# %%
df.iloc[:,4:len(df)] #gets rid of x y long and lat
# df.head()
# Out:
#           565.79    575.77    585.76    595.74    605.72     615.7    625.68  \
# 0       0.042188  0.042188  0.042188  0.042188  0.042188  0.042188  0.042188
# 1       0.042568  0.042568  0.042568  0.042568  0.042568  0.042568  0.042568
# 2       0.043146  0.043146  0.043146  0.043146  0.043146  0.043146  0.043146
# 3       0.040957  0.040957  0.040957  0.040957  0.040957  0.040957  0.040957
# 4       0.040144  0.040144  0.040144  0.040144  0.040144  0.040144  0.040144
# ...          ...       ...       ...       ...       ...       ...       ...
# 179923  0.028051  0.028051  0.028051  0.028051  0.028051  0.028051  0.028051
# 179924  0.028051  0.028051  0.028051  0.028051  0.028051  0.028051  0.028051
# 179925  0.027515  0.027515  0.027515  0.027515  0.027515  0.027515  0.027515
# 179926  0.027232  0.027232  0.027232  0.027232  0.027232  0.027232  0.027232
# 179927  0.026943  0.026943  0.026943  0.026943  0.026943  0.026943  0.026943
#
# ...

# %%
sc = StandardScaler().fit_transform(df)
# sc  =df

# %%
embedding = umap.UMAP(n_neighbors=5,
                      min_dist=0.3,
                      metric='correlation').fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\josep\Documents\Joseph\crater\.venv\Lib\site-packages\numba\core\serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function _numba_unpickle at 0x000001D22DA96020> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ...

# %%
embedding2 = umap.UMAP(n_neighbors=5,
                      min_dist=0.3,
                      metric='correlation').fit_transform(sc)

# %%
embedding3 = umap.UMAP(n_neighbors=10,
                      min_dist=0.3,
                      metric='correlation').fit_transform(sc)

# %%
embedding4 = umap.UMAP(n_neighbors=10,
                      min_dist=0.1,
                      metric='correlation').fit_transform(sc)

# %%
embedding4 = umap.UMAP(n_neighbors=10,
                      min_dist=0.01,
                      metric='correlation').fit_transform(sc)

# %%
embedding5 = umap.UMAP(n_neighbors=10,
                      min_dist=0.001,
                      metric='correlation').fit_transform(sc)

# %%
embedding6 = umap.UMAP(n_neighbors=30,
                      min_dist=0.001,
                      metric='correlation').fit_transform(sc)

# %%
metric = 'euclidean'
embedding7 = umap.UMAP(n_neighbors= 50,
                      min_dist=0.001,
                      metric=metric).fit_transform(sc)

# %%
metric = 'euclidean'
embedding72 = umap.UMAP(n_neighbors= 100,
                      min_dist=0.001,
                      metric=metric).fit_transform(sc)

# %%
metric = 'euclidean'
embedding72 = umap.UMAP(n_neighbors= 300,
                      min_dist=0.001,
                      metric=metric).fit_transform(sc)

# %%
metric = 'euclidean'
embeddin71 = umap.UMAP(n_neighbors= 30,
                      min_dist=0.001,
                      metric=metric).fit_transform(sc)

# %%
metric = 'mahalanobis'
embedding10 = umap.UMAP(n_neighbors= 50,
                      min_dist=0.001,
                      metric=metric).fit_transform(sc)
# Out:
# c:\Users\josep\Documents\Joseph\crater\.venv\Lib\site-packages\pynndescent\pynndescent_.py:947: UserWarning: Failed to correctly find n_neighbors for some samples. Results may be less than ideal. Try re-running with different parameters.
#   warn(

# %% [markdown]
# try:
# mahalanobis (no need to standardize) (dogwater)
# haversine (should be eucledian but better) (actually bad)
# vincenty (may have to program it but should be haversine but better)
#
# tried:
# cosine (wose than euc & has striations but has some interesting stuff)
# chebyshev (baaaad)
# correlation (meh)
#
# https://scikit-learn.org/0.24/modules/generated/sklearn.neighbors.DistanceMetric.html

# %%
embedding8 = umap.UMAP(n_neighbors=80,
                      min_dist=0.001,
                      metric='correlation').fit_transform(sc)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\josep\Documents\Joseph\crater\.venv\Lib\site-packages\numba\core\serialize.py:30, in _numba_unpickle(address, bytedata, hashed)
#      27 _unpickled_memo = {}
# ---> 30 def _numba_unpickle(address, bytedata, hashed):
#      31     """Used by `numba_unpickle` from _helperlib.c
#      32
#      33     Parameters
#    (...)
#      42         unpickled object
#      43     """
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# SystemError: <function _numba_unpickle at 0x000001D22DA96020> returned a result with an exception set
#
# The above exception was the direct cause of the following exception:
#
# SystemError                               Traceback (most recent call last)
# ...

# %%
embedding9 = umap.UMAP(n_neighbors=300,
                      min_dist=0.001,
                      metric='correlation').fit_transform(sc)

# %% [markdown]
# add https://github.com/lmcinnes/pynndescent

# %%
plt.scatter(
    embedding[:, 0],
    embedding[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=5, min_dist=0.3, metric=correlation');

# %%
plt.scatter(
    embedding2[:, 0],
    embedding2[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=5, min_dist=0.3,metric=correlation')
# Out:
# Text(0.5, 1.0, 'n_neighbors=5, min_dist=0.3,metric=correlation')

# %%
plt.scatter(
    embedding3[:, 0],
    embedding3[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
# plt.markersize  = 1
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=10, min_dist=0.3,metric=correlation');

# %%
plt.scatter(
    embedding4[:, 0],
    embedding4[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
# plt.markersize  = 1
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=10, min_dist=0.1,metric=correlation');

# %%
plt.scatter(
    embedding4[:, 0],
    embedding4[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
# plt.markersize  = 1
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=10, min_dist=0.01,metric=correlation');

# %%
plt.scatter(
    embedding5[:, 0],
    embedding5[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
# plt.markersize  = 1
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=30, min_dist=0.001,metric=correlation');

# %%
plt.scatter(
    embedding6[:, 0],
    embedding6[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
# plt.markersize  = 1
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=10, min_dist=0.001,metric=correlation');

# %%
plt.scatter(
    embedding7[:, 0],
    embedding7[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
# plt.markersize  = 1
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=50, min_dist=0.001,metric= '+ metric)
# Out:
# Text(0.5, 1.0, 'n_neighbors=50, min_dist=0.001,metric=euclidean')

# %%
plt.scatter(    embedding8[:, 0],
    embedding8[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
# plt.markersize  = 1
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=80, min_dist=0.001,metric=correlation')
# Out:
# Text(0.5, 1.0, 'n_neighbors=80, min_dist=0.01,metric=correlation')

# %%
plt.scatter(    embedding72[:, 0],
    embedding72[:, 1],
    # c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    0.1
)
# plt.markersize  = 1
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors=300, min_dist=0.001,metric=correlation')
# Out:
# Text(0.5, 1.0, 'n_neighbors=300, min_dist=0.001,metric=correlation')

# %%
print (embedding72)
# Out:
# [[ 0.8499844 -8.239172 ]
#  [ 1.4456737 -8.375076 ]
#  [ 2.0473082 -8.465732 ]
#  ...
#  [-1.2198861  9.741035 ]
#  [-1.1754464  9.996534 ]
#  [-1.1690544  9.969848 ]]

# %%
k = 4
embed = embedding72
neighs = 100

Kmean = KMeans(n_clusters=k)
label = Kmean.fit_predict(embed)
plt.scatter(embed[ : , 0], embed[ : , 1], s =.1)
# print("teeeh")
print(label.size)
# color = iter(plt.rainbow(np.linspace(0, 1, k)))
# 'hot' used for centroids
cmap = plt.get_cmap('Greens', k)
cmaper = plt.get_cmap('gray', k+1)
u_labels = np.unique(label) #is used to assign each point to its color

for i in range(k):
    plt.scatter(embed[label == i][ : , 0], embed[label == i][ : , 1], s =.1, color=cmap(i))
    # plt.scatter(embed[label == i][ : , 0], embed[label == i][ : , 1], s =.1, c = embed.label, cmap = 'prism')
    plt.scatter(Kmean.cluster_centers_[i][0], Kmean.cluster_centers_[i][1], s=50, color=cmaper(i), marker='s')
plt.gca().set_aspect('equal', 'datalim')
plt.title('n_neighbors= '+ str(neighs)+', min_dist=0.001,metric= '+ metric)
plt.show()
# Out:
# c:\Users\josep\Documents\Joseph\crater\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# 179928

# %%
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np

from sklearn.cluster import KMeans


X = embed
# y = embed[ : , 1]

range_n_clusters = [2, 3, 4, 5, 6]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(X)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(
        X[:, 0], X[:, 1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
    )

    # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(
        centers[:, 0],
        centers[:, 1],
        marker="o",
        c="white",
        alpha=1,
        s=200,
        edgecolor="k",
    )

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(
        "Silhouette analysis for KMeans clustering on sample data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# c:\Users\josep\Documents\Joseph\crater\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# For n_clusters = 2 The average silhouette_score is : 0.49030098
# c:\Users\josep\Documents\Joseph\crater\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# For n_clusters = 3 The average silhouette_score is : 0.5050241
# c:\Users\josep\Documents\Joseph\crater\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# ...

# %%
from matplotlib import colormaps
list(colormaps)
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %%
ncols, nrows = 408, 441
data = label.reshape(nrows, ncols) 
# data = label.reshape(nrows, ncols).transpose()
neighs = 300
# creating a plot 
pixel_plot = plt.figure() 
  
# plotting a plot 
# pixel_plot.add_axes() 
# cmap = plt.get_cmap('prism', k)
# customizing plot 
plt.title("image") 
pixel_plot = plt.imshow( 
  data, cmap='Greens', interpolation='nearest', origin='lower') 
  
plt.colorbar(pixel_plot) 
  
# save a plot 
plt.savefig('pixel_plot.png') 
plt.title(" neighs = " + str(neighs) + ", k = "+ str(k) +  ", metric: "+ metric)
  
# show plot 
plt.show(pixel_plot)

# %%
k = 15
embed = embedding72
neighs = 100

Kmean = KMeans(n_clusters=k)
label = Kmean.fit_predict(embed)

ncols, nrows = 408, 441
data = label.reshape(nrows, ncols) 
np.save('k'+str(k)+'data', data) # save the file as "outfile_name.npy" 
dfer = pd.DataFrame(data)
dfer.to_csv('k'+str(k)+'data.csv')
# Out:
# c:\Users\josep\Documents\Joseph\crater\.venv\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
np.save('k'+str(k)+'data', data) # save the file as "outfile_name.npy" 
dfer = pd.DataFrame(data)
dfer.to_csv('k'+str(k)+'data.csv')
